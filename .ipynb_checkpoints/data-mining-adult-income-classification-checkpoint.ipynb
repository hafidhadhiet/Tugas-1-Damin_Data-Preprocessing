# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/adult-census-income/adult.csv

# %%
# Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
import graphviz 
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler 
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression

# %%
# Pipeline Libraries

from sklearn import neighbors
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from tabulate import tabulate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA

# %%
# Model Libraries

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_curve, auc, plot_roc_curve
from sklearn import tree
from sklearn import neighbors
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score as acc
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

# %%
data = pd.read_csv("/kaggle/input/adult-census-income/adult.csv", na_values='?')

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %% [markdown]
# # **Pre-Processing Data**

# %%
data.columns=['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race','sex','capital_gain','capital_loss','hours_per_week','native_country','income']

# %%
data.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# income               0
# dtype: int64

# %%
# Replacing the NA values with mode 
for col in ['workclass', 'occupation', 'native_country']:
    data[col].fillna(data[col].mode()[0], inplace=True)

# %% [markdown]
# 'education' and 'education_num' represent same kind of data. So, One of them can be removed.

# %%
data = data.drop(['education'],axis=1)

# %%
# Replacing '50K' with '0' and '1'

data = data.replace({'<=50K':0,'>50K':1})
data = data.replace({'<=50K':0,'>50K':1})

# %% [markdown]
# # **Data Exploration**

# %%
# Lists that will be manipulated in the data processing
list_columns = []
list_categorical_col = []
list_numerical_col = []

# %%
def get_col(df: 'dataframe', type_descr: 'numpy') -> list:
    """
    Function get list columns 
    
    Args:
    type_descr
        np.number, np.object -> return list with all columns
        np.number            -> return list numerical columns 
        np.object            -> return list object columns
    """
    try:
        col = (df.describe(include=type_descr).columns)  # pandas.core.indexes.base.Index  
    except ValueError:
        print(f'Dataframe not contains {type_descr} columns !', end='\n')    
    else:
        return col.tolist()

# %%
list_numerical_col = get_col(df=data,
                             type_descr=np.number)
list_categorical_col = get_col(df=data,
                               type_descr=np.object)
list_columns = get_col(df=data,
                       type_descr=[np.object, np.number])

# %%
list_numerical_col
# Out:
# ['age',
#  'fnlwgt',
#  'education_num',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week',
#  'income']

# %%
list_categorical_col
# Out:
# ['workclass',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country']

# %%
x = data[list_numerical_col].hist(figsize=[25,22], 
                                density=True, 
                                bins=25, 
                                grid=False, 
                                color='orange', 
                                zorder=2, 
                                rwidth=0.9)

# %% [markdown]
# **Observation :**
# Majority of value in 'capital_gain' and 'capital_loss' is 0 (zero).So we can drop both columns as they are sparse.

# %%
sns.pairplot(data, kind='scatter', diag_kind='kde',corner=True, hue='income')

# %% [markdown]
# **Observation :** There is no particular feature which is highly correlated.

# %%
data.corr()
# Out:
#                      age    fnlwgt  education_num  capital_gain  capital_loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education_num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital_gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital_loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours_per_week  0.068756 -0.018768       0.148123      0.078409      0.054256
# income          0.234037 -0.009463       0.335154      0.223329      0.150526
#
#                 hours_per_week    income
# age                   0.068756  0.234037
# fnlwgt               -0.018768 -0.009463
# education_num         0.148123  0.335154
# capital_gain          0.078409  0.223329
# capital_loss          0.054256  0.150526
# hours_per_week        1.000000  0.229689
# income                0.229689  1.000000

# %%
sns.heatmap(data.corr(), annot=True, cmap="PiYG")
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observation :**
# - Except 'fnlwgt', all numerical features are positively correlated with 'income'.

# %%
eda_percentage = data['income'].value_counts(normalize = True).rename_axis('income').reset_index(name = 'Percentage')
ax = sns.barplot(x = 'income', y = 'Percentage', data = eda_percentage.head(10), palette='RdGy_r')
eda_percentage
# Out:
#    income  Percentage
# 0       0     0.75919
# 1       1     0.24081

# %% [markdown]
# **Observation :**
# - The number of records with income "<=50K" is around 76% and ">50K" is around 24%.
# - The class distribution is moderate imbalanced.

# %%
def age_group(x):
    x = int(x)
    x = abs(x)
    if(x <= 18 ):
        return "Less than 18"    
    if( 18 < x < 31 ):
        return "19-30"
    if( 30 < x < 41 ):
        return "31-40"
    if( 40 < x < 51 ):
        return "41-50"
    if( 50 < x < 61 ):
        return "51-60"
    if( 60 < x < 71 ):
        return "61-70"
    else:
        return "Greater than 70"

data['age_group'] = data['age'].apply(age_group)

# %%
plt.figure(figsize=(12,6))
order_list = ['Less than 18','19-30', '31-40', '41-50', '51-60', '61-70', 'Greater than 70']
sns.countplot(data['age_group'], hue = data['income'], palette='autumn_r', order = order_list)
plt.title('Income of Individuals of Different Age Groups', fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Observation :**
# - There is gradual decrease in number of people earning less than $50K'.
#
# - People earning more than $50K rise as they become older, up to a point.

# %%
plt.figure(figsize=(12,6))
#order_list = ['19-30', '31-40', '41-50', '51-60', '61-70', 'Greater than 70']
sns.countplot(data['workclass'], hue = data['income'],  palette='autumn_r')
plt.title('Income of Individuals of Different Working CLasses', fontsize=14)
plt.xticks(fontsize=10,rotation = 45)
plt.yticks(fontsize=10)
plt.legend(fontsize=10)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Observation**
# - There is significant income difference between people working in 'Private' working class.
# - The People working at 'federal government', 'local government' have almost similar number of people on both classes.
# - The 'Self Employed included' is the only working class having more people in more tha >50K category instead of less than <=$50K.

# %%
ig = plt.figure(figsize = (12, 6))
sns.catplot(x = 'relationship', y='hours_per_week', data=data, kind="violin")
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Not-in-family'),
#   Text(1, 0, 'Unmarried'),
#   Text(2, 0, 'Own-child'),
#   Text(3, 0, 'Other-relative'),
#   Text(4, 0, 'Husband'),
#   Text(5, 0, 'Wife')])

# %%
sns.displot(data, x='age',kind= 'kde', hue = 'income', fill= 'income')

# %% [markdown]
# # **Models**

# %%
data.head()
# Out:
#    age workclass  fnlwgt  education_num marital_status         occupation  \
# 0   90   Private   77053              9        Widowed     Prof-specialty
# 1   82   Private  132870              9        Widowed    Exec-managerial
# 2   66   Private  186061             10        Widowed     Prof-specialty
# 3   54   Private  140359              4       Divorced  Machine-op-inspct
# 4   41   Private  264663             10      Separated     Prof-specialty
#
#     relationship   race     sex  capital_gain  capital_loss  hours_per_week  \
# 0  Not-in-family  White  Female             0          4356              40
# 1  Not-in-family  White  Female             0          4356              18
# 2      Unmarried  Black  Female             0          4356              40
# 3      Unmarried  White  Female             0          3900              40
# 4      Own-child  White  Female             0          3900              40
#
#   native_country  income        age_group
# 0  United-States       0  Greater than 70
# 1  United-States       0  Greater than 70
# 2  United-States       0            61-70
# 3  United-States       0            51-60
# 4  United-States       0            41-50

# %%
data = data.drop(columns=['age_group'])

# %%
sns.histplot(data, x='age')
plt.axvline(np.mean(data['age']), color='crimson', ls=':')
plt.show()

# %% [markdown]
# Applying **Standardization** as it handles outliers better compared to Normalization.

# %%
# Standardize the inputs
scaler = StandardScaler()
list_scaling = ['age','fnlwgt','education_num','capital_gain','capital_loss','hours_per_week']
data[list_scaling] = scaler.fit_transform(data[list_scaling])

# %%
for feature in list_categorical_col:
    le = preprocessing.LabelEncoder()
    data[feature] = le.fit_transform(data[feature])

# %% [markdown]
# One-Hot encoding is also an option for label encoding.

# %%
# Train-Test Split - Hold-out Method
X = data.drop(columns=['income'])
y = data.income

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# # KNN

# %%
# Generate a kNN model
knn_model = neighbors.KNeighborsClassifier()
print(knn_model.get_params())

# Distance and Weight Array
n = np.arange(1,21)
dist = np.array(['euclidean', 'manhattan'])
weight = np.array(['uniform', 'distance'])

#Finding Best Performing Parameters
results = pd.DataFrame(columns = ['#neighbors','distance', 'weight', 'acc_score'])
index = 0
for i in n:
  for j in dist:
    for k in weight:
      knn_model = neighbors.KNeighborsClassifier(n_neighbors=i, metric=j, weights=k)
      knn_model.fit(X_train, y_train)
      pred = knn_model.predict(X_test)
      acc_score = accuracy_score(y_test, pred)
      #rmse = mean_squared_error(y_test, pred, squared=False)
      results.loc[index] = [i,j,k,acc_score]
      index +=1
print('All results')
print(tabulate(results, headers = 'keys', tablefmt = 'psql'))
print('Best performing model')      
print(tabulate(results[results['acc_score']==results['acc_score'].max()], headers = 'keys', tablefmt = 'psql'))
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# All results
# +----+--------------+------------+----------+-------------+
# |    |   #neighbors | distance   | weight   |   acc_score |
# |----+--------------+------------+----------+-------------|
# |  0 |            1 | euclidean  | uniform  |    0.801822 |
# |  1 |            1 | euclidean  | distance |    0.801822 |
# |  2 |            1 | manhattan  | uniform  |    0.800594 |
# |  3 |            1 | manhattan  | distance |    0.800594 |
# |  4 |            2 | euclidean  | uniform  |    0.815641 |
# |  5 |            2 | euclidean  | distance |    0.801822 |
# |  6 |            2 | manhattan  | uniform  |    0.814822 |
# |  7 |            2 | manhattan  | distance |    0.800594 |
# |  8 |            3 | euclidean  | uniform  |    0.821476 |
# |  9 |            3 | euclidean  | distance |    0.820248 |
# | 10 |            3 | manhattan  | uniform  |    0.821271 |
# | 11 |            3 | manhattan  | distance |    0.818508 |
# | 12 |            4 | euclidean  | uniform  |    0.826185 |
# | 13 |            4 | euclidean  | distance |    0.821271 |
# | 14 |            4 | manhattan  | uniform  |    0.827311 |
# | 15 |            4 | manhattan  | distance |    0.820043 |
# | 16 |            5 | euclidean  | uniform  |    0.831917 |
# | 17 |            5 | euclidean  | distance |    0.828437 |
# | 18 |            5 | manhattan  | uniform  |    0.833453 |
# | 19 |            5 | manhattan  | distance |    0.829563 |
# | 20 |            6 | euclidean  | uniform  |    0.831508 |
# | 21 |            6 | euclidean  | distance |    0.829256 |
# | 22 |            6 | manhattan  | uniform  |    0.830996 |
# | 23 |            6 | manhattan  | distance |    0.830484 |
# | 24 |            7 | euclidean  | uniform  |    0.834272 |
# | 25 |            7 | euclidean  | distance |    0.833146 |
# | 26 |            7 | manhattan  | uniform  |    0.835705 |
# | 27 |            7 | manhattan  | distance |    0.834476 |
# | 28 |            8 | euclidean  | uniform  |    0.831917 |
# | 29 |            8 | euclidean  | distance |    0.832839 |
# | 30 |            8 | manhattan  | uniform  |    0.834272 |
# | 31 |            8 | manhattan  | distance |    0.833965 |
# | 32 |            9 | euclidean  | uniform  |    0.834169 |
# | 33 |            9 | euclidean  | distance |    0.834681 |
# | 34 |            9 | manhattan  | uniform  |    0.836728 |
# | 35 |            9 | manhattan  | distance |    0.834681 |
# | 36 |           10 | euclidean  | uniform  |    0.8355   |
# | 37 |           10 | euclidean  | distance |    0.8355   |
# | 38 |           10 | manhattan  | uniform  |    0.835193 |
# | 39 |           10 | manhattan  | distance |    0.835295 |
# | 40 |           11 | euclidean  | uniform  |    0.836831 |
# | 41 |           11 | euclidean  | distance |    0.836728 |
# | 42 |           11 | manhattan  | uniform  |    0.83765  |
# | 43 |           11 | manhattan  | distance |    0.837036 |
# | 44 |           12 | euclidean  | uniform  |    0.834169 |
# | 45 |           12 | euclidean  | distance |    0.837752 |
# | 46 |           12 | manhattan  | uniform  |    0.836524 |
# | 47 |           12 | manhattan  | distance |    0.837957 |
# | 48 |           13 | euclidean  | uniform  |    0.83591  |
# | 49 |           13 | euclidean  | distance |    0.837036 |
# | 50 |           13 | manhattan  | uniform  |    0.840311 |
# | 51 |           13 | manhattan  | distance |    0.836831 |
# | 52 |           14 | euclidean  | uniform  |    0.834783 |
# | 53 |           14 | euclidean  | distance |    0.838059 |
# | 54 |           14 | manhattan  | uniform  |    0.837445 |
# | 55 |           14 | manhattan  | distance |    0.83898  |
# | 56 |           15 | euclidean  | uniform  |    0.836217 |
# | 57 |           15 | euclidean  | distance |    0.836831 |
# | 58 |           15 | manhattan  | uniform  |    0.840925 |
# | 59 |           15 | manhattan  | distance |    0.838366 |
# | 60 |           16 | euclidean  | uniform  |    0.836217 |
# | 61 |           16 | euclidean  | distance |    0.83765  |
# | 62 |           16 | manhattan  | uniform  |    0.837957 |
# | 63 |           16 | manhattan  | distance |    0.839902 |
# | 64 |           17 | euclidean  | uniform  |    0.837445 |
# | 65 |           17 | euclidean  | distance |    0.838059 |
# | 66 |           17 | manhattan  | uniform  |    0.841232 |
# | 67 |           17 | manhattan  | distance |    0.840311 |
# | 68 |           18 | euclidean  | uniform  |    0.837343 |
# | 69 |           18 | euclidean  | distance |    0.838162 |
# | 70 |           18 | manhattan  | uniform  |    0.83898  |
# | 71 |           18 | manhattan  | distance |    0.839288 |
# | 72 |           19 | euclidean  | uniform  |    0.836217 |
# | 73 |           19 | euclidean  | distance |    0.838059 |
# | 74 |           19 | manhattan  | uniform  |    0.840516 |
# | 75 |           19 | manhattan  | distance |    0.841744 |
# | 76 |           20 | euclidean  | uniform  |    0.83591  |
# | 77 |           20 | euclidean  | distance |    0.837752 |
# | 78 |           20 | manhattan  | uniform  |    0.838673 |
# | 79 |           20 | manhattan  | distance |    0.841028 |
# +----+--------------+------------+----------+-------------+
# Best performing model
# +----+--------------+------------+----------+-------------+
# |    |   #neighbors | distance   | weight   |   acc_score |
# |----+--------------+------------+----------+-------------|
# | 75 |           19 | manhattan  | distance |    0.841744 |
# +----+--------------+------------+----------+-------------+

# %%
knn_model = neighbors.KNeighborsClassifier(n_neighbors=20, metric='manhattan', weights='uniform')
knn_model.fit(X_train, y_train)
pred_knn = knn_model.predict(X_test)

acc_score_knn = accuracy_score(y_test, pred_knn)
recall_knn = recall_score(y_test, pred_knn)
precision_knn = precision_score(y_test, pred_knn)
f1_knn = f1_score(y_test, pred_knn)
roc_knn = roc_auc_score(y_test, pred_knn)

print(classification_report(y_test, pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      7429
#            1       0.72      0.53      0.61      2340
#
#     accuracy                           0.84      9769
#    macro avg       0.79      0.73      0.76      9769
# weighted avg       0.83      0.84      0.83      9769

# %% [markdown]
# # Logistic

# %%
# Create a hyperparameter grid for LogisticRegression
log_reg_grid = {"C": np.logspace(-4, 4, 20),
                "solver": ["liblinear"]}

# Create a hyperparameter grid for RandomForestClassifier
rf_grid = {"n_estimators": np.arange(10, 1000, 50),
           "max_depth": [None, 3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2)}
# Tune LogisticRegression

np.random.seed(42)

# Setup random hyperparameter search for LogisticRegression
rs_log_reg = RandomizedSearchCV(LogisticRegression(),
                                param_distributions=log_reg_grid,
                                cv=5,
                                n_iter=20,
                                verbose=True)

# Fit random hyperparameter search model for LogisticRegression
rs_log_reg.fit(X_train, y_train)

rs_log_reg.best_params_

rs_log_reg.score(X_test, y_test)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   13.0s finished
# 0.8267990582454704

# %% [markdown]
# # Naive Bayes ( Gaussian NB )

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred_nb = nb.predict(X_test)
#print(classification_report(y_test, y_pred_nb))

# %%
accuracy_nb = accuracy_score(y_test, y_pred_nb)
print("Naive Bayes Gaussian Accuracy : ", accuracy_nb)
# Out:
# Naive Bayes Gaussian Accuracy :  0.8034599242501791

# %%
recall_nb = recall_score(y_test, y_pred_nb)
precision_nb = precision_score(y_test, y_pred_nb)
f1_nb = f1_score(y_test, y_pred_nb)
roc_nb = roc_auc_score(y_test, y_pred_nb)
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88      7429
#            1       0.68      0.33      0.45      2340
#
#     accuracy                           0.80      9769
#    macro avg       0.75      0.64      0.66      9769
# weighted avg       0.79      0.80      0.78      9769

# %% [markdown]
# # Decision Tree Classifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
pred_decision_tree = model.predict (X_test)
print('Accuracy: ', accuracy_score(y_test, pred_decision_tree))
# Out:
# Accuracy:  0.8176886068174839

# %%
# Hyper Parameter Tuning - Decision Tree
ind = 1
crit = ['gini', 'entropy']
df_results = pd.DataFrame(columns = ['depth', 'puritymethod', 'Accuracy'])

for i in np.arange(1, 31):
  for j in crit:
    model = DecisionTreeClassifier(max_depth=i, criterion=j)
    model.fit(X_train, y_train)
    pred = model.predict (X_test)
    df_results.loc[ind] = [i, j, accuracy_score(y_test, pred)]
    ind+=1
sns.lineplot(x = 'depth', y = 'Accuracy', hue='puritymethod', data = df_results)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='Accuracy'>

# %%
print('Best performing model - Decision Tree')      
print(tabulate(df_results[df_results['Accuracy']==df_results['Accuracy'].max()], headers = 'keys', tablefmt = 'psql'))
# Out:
# Best performing model - Decision Tree
# +----+---------+----------------+------------+
# |    |   depth | puritymethod   |   Accuracy |
# |----+---------+----------------+------------|
# | 21 |      11 | gini           |   0.859249 |
# +----+---------+----------------+------------+

# %% [markdown]
# # Neural  Networks

# %%
model = MLPClassifier(max_iter=800, learning_rate_init= 0.005)
model.fit(X_train, y_train)
pred = model.predict(X_test)

acc_neural= accuracy_score(y_test,pred)
print("Accuracy Score - Neural Networks ",acc_neural)
# Out:
# Accuracy Score - Neural Networks  0.8544375063977889

# %%
result = pd.DataFrame(columns=['Learning Rate', 'Transfer Function',  'Accuracy'])
lr = [0.00001, 0.0001, 0.01, 0.03, 1, 3, 10]
transfer_function = ['identity', 'logistic', 'tanh', 'relu']
k=0
for i in lr:
  for j in transfer_function:
    model = MLPClassifier(learning_rate_init= i, activation=j)
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    result.loc[k] = [i, j,  accuracy_score(y_test, pred)]
    k+=1
#print(tabulate(result, headers=result.columns, tablefmt='grid'))
print('All results')
print(tabulate(results, headers = result.columns, tablefmt = 'psql'))
print('Best performing model')      
print(tabulate(results[results['Accuracy']==results['Accuracy'].max()], headers = 'keys', tablefmt = 'psql'))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
